# %%
import os
import numpy as np
import pandas as pd
import torch
from tqdm.auto import tqdm
import evaluate
from transformers import WhisperProcessor, WhisperForConditionalGeneration
from dataclasses import dataclass


@dataclass
class Config:
    MODEL_PATH       = "./whisper-ja-asmr-small-1-earlyst/final"   # your fine-tuned model dir
    MANIFEST_CSV     = "./manifest/preprocessed-segments-index.csv"
    TEST_RATIO       = 0.1
    RANDOM_SEED      = 42
    DEVICE           = "cuda" if torch.cuda.is_available() else "cpu"

# 1) Load & split out the test set
df = pd.read_csv(Config.MANIFEST_CSV)
df = df[df.lang == "ja"].reset_index(drop=True)
_, test_df = np.split(
    df.sample(frac=1, random_state=Config.RANDOM_SEED),
    [ int(len(df)*(1 - Config.TEST_RATIO)) ]
)
print(f"▶ Test examples: {len(test_df)}")

# 2) Prepare metrics
wer_metric = evaluate.load("wer")
cer_metric = evaluate.load("cer")

# 3) Load model + processor, clear any forced prompts
processor = WhisperProcessor.from_pretrained(Config.MODEL_PATH)
model     = WhisperForConditionalGeneration.from_pretrained(Config.MODEL_PATH).to(Config.DEVICE)
# Out:
# ▶ Test examples: 1698
# /home/rehab/research/whisperlaz/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
#––– Before the loop, we’ve already set:
# model.generation_config.num_beams            = 3
# model.generation_config.no_repeat_ngram_size = 2
# model.generation_config.repetition_penalty    = 1.5
# model.generation_config.length_penalty        = 1.0
# model.generation_config.early_stopping        = True

# (You can also set:)
model.generation_config.max_new_tokens = 50  # generate at most 50 new tokens

#––– 4) Inference loop with max_new_tokens
records = []
for _, row in tqdm(test_df.iterrows(), total=len(test_df), desc="Eval with anti-repeat"):
    data      = np.load(row["npz_path"], allow_pickle=True)
    audio_arr = data["audio"].astype(np.float32)
    reference = str(data["text"])

    # tokenize + mask
    inputs = processor(
        audio_arr,
        sampling_rate=16000,
        return_tensors="pt",
        return_attention_mask=True
    )
    input_feats    = inputs.input_features.to(Config.DEVICE)
    attention_mask = inputs.attention_mask.to(Config.DEVICE)

    with torch.no_grad():
        gen_ids = model.generate(
            input_feats,
            attention_mask=attention_mask,
            # GENERATION-ONLY cap:
            max_new_tokens=50,

            # anti-repetition (redundant if you set on generation_config, but explicit is fine)
            num_beams=model.generation_config.num_beams,
            no_repeat_ngram_size=model.generation_config.no_repeat_ngram_size,
            repetition_penalty=model.generation_config.repetition_penalty,
            length_penalty=model.generation_config.length_penalty,
            early_stopping=model.generation_config.early_stopping,

            # ensure no old prompts
            forced_decoder_ids=None,
        )

    hypothesis = processor.batch_decode(gen_ids, skip_special_tokens=True)[0]

    records.append({
        "npz_path":   row["npz_path"],
        "reference":  reference,
        "prediction": hypothesis
    })
# Out:
# Eval with anti-repeat:   0%|          | 0/1698 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 29
#      26 attention_mask = inputs.attention_mask.to(Config.DEVICE)
#      28 with torch.no_grad():
# ---> 29     gen_ids = model.generate(
#      30         input_feats,
#      31         attention_mask=attention_mask,
#      32         # GENERATION-ONLY cap:
#      33         max_new_tokens=50,
#      34
#      35         # anti-repetition (redundant if you set on generation_config, but explicit is fine)
#      36         num_beams=model.generation_config.num_beams,
#      37         no_repeat_ngram_size=model.generation_config.no_repeat_ngram_size,
#      38         repetition_penalty=model.generation_config.repetition_penalty,
#      39         length_penalty=model.generation_config.length_penalty,
#      40         early_stopping=model.generation_config.early_stopping,
#      41
#      42         # ensure no old prompts
#      43         forced_decoder_ids=None,
#      44     )
#      46 hypothesis = processor.batch_decode(gen_ids, skip_special_tokens=True)[0]
#      48 records.append({
#      49     "npz_path":   row["npz_path"],
#      50     "reference":  reference,
#      51     "prediction": hypothesis
#      52 })
#
# File ~/research/whisperlaz/.venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:619, in WhisperGenerationMixin.generate(self, input_features, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, return_timestamps, task, language, is_multilingual, prompt_ids, prompt_condition_type, condition_on_prev_tokens, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, num_segment_frames, attention_mask, time_precision, time_precision_features, return_token_timestamps, return_segments, return_dict_in_generate, force_unique_generate_call, **kwargs)
#     613 self._set_prompt_condition_type(
#     614     generation_config=generation_config,
#     615     prompt_condition_type=prompt_condition_type,
#     616 )
#     618 # pass self.config for backward compatibility
# --> 619 init_tokens = self._retrieve_init_tokens(
#     620     input_features,
#     621     batch_size=batch_size,
#     622     generation_config=generation_config,
#     623     config=self.config,
#     624     num_segment_frames=num_segment_frames,
#     625     kwargs=kwargs,
#     626 )
#     627 # passing `decoder_input_ids` is deprecated - the only exception is for assisted generation
#     628 # where the input ids are handled explicitly by the generate method
#     629 self._check_decoder_input_ids(kwargs=kwargs)
#
# File ~/research/whisperlaz/.venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:1470, in WhisperGenerationMixin._retrieve_init_tokens(self, input_features, batch_size, generation_config, config, num_segment_frames, kwargs)
#    1467     lang_ids = [language_to_id(l) for l in languages]
#    1468 elif hasattr(generation_config, "lang_to_id") and is_lang_id_undefined:
#    1469     # language is not defined or intentially set to `None` to trigger language detection
# -> 1470     lang_ids = self.detect_language(
#    1471         input_features=input_features,
#    1472         encoder_outputs=kwargs.get("encoder_outputs", None),
#    1473         generation_config=generation_config,
#    1474         num_segment_frames=num_segment_frames,
#    1475     ).tolist()
#    1476 if lang_ids is not None:
#    1477     # append or replace lang_ids to init_tokens
#    1478     for i in range(len(init_tokens)):
#
# File ~/research/whisperlaz/.venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:1581, in WhisperGenerationMixin.detect_language(self, input_features, encoder_outputs, generation_config, num_segment_frames)
#    1577 non_lang_mask[list(generation_config.lang_to_id.values())] = False
#    1579 logits[:, non_lang_mask] = -np.inf
# -> 1581 lang_ids = logits.argmax(-1)
#    1583 return lang_ids
#
# KeyboardInterrupt:

# %%
# 5) Compute overall WER/CER
df_results = pd.DataFrame(records)
wer = wer_metric.compute(predictions=df_results.prediction, references=df_results.reference)
cer = cer_metric.compute(predictions=df_results.prediction, references=df_results.reference)
print(f"\nOverall  → WER: {wer:.3f}, CER: {cer:.3f}\n")

# 6) Show per-example DataFrame
df_results.head(10)
# Out:
# Overall  → WER: 1.070, CER: 0.560
#                                             npz_path  \
# 0  ./preprocessed_segments/channel_1_K-wGFJzWXEM_...
# 1  ./preprocessed_segments/channel_1__nt_OsOMIXA_...
# 2  ./preprocessed_segments/channel_1__nt_OsOMIXA_...
# 3  ./preprocessed_segments/channel_1__V7K7h1BPmk_...
# 4  ./preprocessed_segments/channel_1_K-wGFJzWXEM_...
# 5  ./preprocessed_segments/channel_1_YExNnL0_WOQ_...
# 6  ./preprocessed_segments/channel_1_aWCumaPnmIw_...
# 7  ./preprocessed_segments/channel_1__nt_OsOMIXA_...
# 8  ./preprocessed_segments/channel_1_K-wGFJzWXEM_...
# 9  ./preprocessed_segments/channel_1_oWq4pn4Lnxk_...
#
#                                 reference  \
# 0                         なかなか大変だなって思いました
# 1           キーピングスタディーレコード はここに当てはまりそうですね
# 2              40番バクツ 2年生が書かれていてその上に当てはまる
# 3                                  毎日のように
# 4                文書1と文章には関連付けて考えてみ ようって話で
# 5                   はい ではお部屋にご案内させていただきます
# 6                利益が全て自分の手元に入るという制度になります。
# 7                                     これは
# 8                                ある意味 復興を
# 9  このように足・消化器官・脳が繋がっているように 体全体が繋がっているんですね
#
#                                           prediction
# 0                                   なかなか大変だなって思いました。
# 1                          スタディーレコード ここに当てはあまりそうですね。
# 2                 40番パクツ 記念数が書かれていてその上に当てはまるものですけども、
# 3                                            毎日のように、
# 4  文章1と文書2を関連つけて考えてみようって話で 文座におかんれんづけて考え てみよってはなし...
# 5                             ではお部屋にご案内させていただきます。はい。
# 6                         その利益が全て自分の手元に入るという制度になります。
# 7                                            これは、はい。
# 8  ある意味 復興をになってもらいたいですけどね あるいみにふっこうを拭くことができるのかもしれ...
# 9               このように足証拠期間脳が繋がっているように体全体がつながってるんですね。

# %%
#%% 6) Listen to a few examples with their predictions
from IPython.display import Audio, display

# Pick the first 5 (or sample randomly: df_results.sample(5, random_state=42))
for idx, row in df_results.head(5).iterrows():
    # Load raw waveform
    audio_arr = np.load(row["npz_path"], allow_pickle=True)["audio"].astype(np.float32)
    
    # Print out the texts
    print(f"▶ Example {idx}")
    print(f"   Reference : {row['reference']}")
    print(f"   Prediction: {row['prediction']}")
    
    # Play the audio
    display(Audio(audio_arr, rate=16000))
    print("-" * 60)
# Out:
# ▶ Example 0
#    Reference : なかなか大変だなって思いました
#    Prediction: なかなか大変だなって思いました。
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ------------------------------------------------------------
# ▶ Example 1
#    Reference : キーピングスタディーレコード はここに当てはまりそうですね
#    Prediction: スタディーレコード ここに当てはあまりそうですね。
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ------------------------------------------------------------
# ▶ Example 2
#    Reference : 40番バクツ 2年生が書かれていてその上に当てはまる
#    Prediction: 40番パクツ 記念数が書かれていてその上に当てはまるものですけども、
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ------------------------------------------------------------
# ▶ Example 3
#    Reference : 毎日のように
#    Prediction: 毎日のように、
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ------------------------------------------------------------
# ▶ Example 4
#    Reference : 文書1と文章には関連付けて考えてみ ようって話で
#    Prediction: 文章1と文書2を関連つけて考えてみようって話で 文座におかんれんづけて考え てみよってはなして分からないんですけどね
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ------------------------------------------------------------
